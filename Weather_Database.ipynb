# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

   # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherDescription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 1 | buchanan
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | freetown
# Processing Record 7 of Set 1 | faanui
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 1 | kamaishi
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | gogrial
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | jiangyou
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | francistown
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | auki
# Processing Record 24 of Set 1 | rocha
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | bhinmal
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | tacuarembo
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | lazaro cardenas
# Processing Record 31 of Set 1 | morehead
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | two hills
# Processing Record 35 of Set 1 | karratha
# Processing Record 36 of Set 1 | coquimbo
# Processing Record 37 of Set 1 | ronne
# Processing Record 38 of Set 1 | bandar-e lengeh
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | klaksvik
# Processing Record 41 of Set 1 | salalah
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | roald
# Processing Record 45 of Set 1 | yumen
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | celestun
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | abashiri
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | mingyue
# Processing Record 10 of Set 2 | saldus
# Processing Record 11 of Set 2 | saint-joseph
# Processing Record 12 of Set 2 | bira
# Processing Record 13 of Set 2 | bac lieu
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | tura
# Processing Record 16 of Set 2 | atambua
# Processing Record 17 of Set 2 | ciudad real
# Processing Record 18 of Set 2 | ewa beach
# Processing Record 19 of Set 2 | hakodate
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | dingle
# Processing Record 23 of Set 2 | sechura
# Processing Record 24 of Set 2 | richards bay
# Processing Record 25 of Set 2 | kahului
# Processing Record 26 of Set 2 | muroto
# Processing Record 27 of Set 2 | tignere
# Processing Record 28 of Set 2 | mersing
# Processing Record 29 of Set 2 | borujan
# City not found. Skipping...
# Processing Record 30 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 31 of Set 2 | west wendover
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | ngama
# Processing Record 34 of Set 2 | tasiilaq
# Processing Record 35 of Set 2 | khorramshahr
# Processing Record 36 of Set 2 | nyurba
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | mango
# Processing Record 39 of Set 2 | arraial do cabo
# Processing Record 40 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | penol
# Processing Record 42 of Set 2 | sitka
# Processing Record 43 of Set 2 | karpuninskiy
# City not found. Skipping...
# Processing Record 44 of Set 2 | ryotsu
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | brewster
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | mehamn
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 3 | qaanaaq
# Processing Record 3 of Set 3 | hilo
# Processing Record 4 of Set 3 | bethlehem
# Processing Record 5 of Set 3 | acapulco
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | lagoa
# Processing Record 8 of Set 3 | sao filipe
# Processing Record 9 of Set 3 | erdaojiang
# Processing Record 10 of Set 3 | ostrovnoy
# Processing Record 11 of Set 3 | paamiut
# Processing Record 12 of Set 3 | taoudenni
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | tiznit
# Processing Record 15 of Set 3 | kavaratti
# Processing Record 16 of Set 3 | north bend
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | parkes
# Processing Record 20 of Set 3 | san roque
# Processing Record 21 of Set 3 | baykit
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | lengshuitan
# Processing Record 24 of Set 3 | adelaide
# Processing Record 25 of Set 3 | korla
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | tamandare
# Processing Record 28 of Set 3 | port-de-paix
# City not found. Skipping...
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | saint-michel-des-saints
# Processing Record 33 of Set 3 | caravelas
# Processing Record 34 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 3 | fortuna
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | inuvik
# Processing Record 38 of Set 3 | ambilobe
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | akyab
# Processing Record 41 of Set 3 | sao joao da barra
# Processing Record 42 of Set 3 | isangel
# Processing Record 43 of Set 3 | skibbereen
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | zongozotla
# Processing Record 47 of Set 3 | port hardy
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | pingzhuang
# Processing Record 50 of Set 3 | oranjemund
# Processing Record 1 of Set 4 | port blair
# Processing Record 2 of Set 4 | alugan
# Processing Record 3 of Set 4 | kumo
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | santa isabel
# Processing Record 6 of Set 4 | ridgecrest
# Processing Record 7 of Set 4 | vestmannaeyjar
# Processing Record 8 of Set 4 | rawson
# Processing Record 9 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | bhadravati
# Processing Record 14 of Set 4 | olot
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | ust-kuyga
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 4 | dhidhdhoo
# Processing Record 20 of Set 4 | dongsheng
# Processing Record 21 of Set 4 | biak
# Processing Record 22 of Set 4 | waipawa
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | mahayag
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | ust-karsk
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | iqaluit
# Processing Record 29 of Set 4 | machida
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | takoradi
# Processing Record 32 of Set 4 | kathmandu
# Processing Record 33 of Set 4 | lata
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | portland
# Processing Record 38 of Set 4 | koungheul
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | vaini
# Processing Record 41 of Set 4 | havoysund
# Processing Record 42 of Set 4 | hualmay
# Processing Record 43 of Set 4 | wagar
# Processing Record 44 of Set 4 | chengde
# Processing Record 45 of Set 4 | egvekinot
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | inirida
# Processing Record 48 of Set 4 | lebu
# Processing Record 49 of Set 4 | senneterre
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | aklavik
# Processing Record 2 of Set 5 | saint george
# Processing Record 3 of Set 5 | yazman
# Processing Record 4 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 5 | broome
# Processing Record 6 of Set 5 | nemuro
# Processing Record 7 of Set 5 | zanjan
# Processing Record 8 of Set 5 | weihe
# Processing Record 9 of Set 5 | geraldton
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | katsuura
# Processing Record 12 of Set 5 | wilmington
# Processing Record 13 of Set 5 | pokaran
# Processing Record 14 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 15 of Set 5 | la gaulette
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto colombia
# Processing Record 17 of Set 5 | bardiyah
# Processing Record 18 of Set 5 | huarmey
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | huaraz
# Processing Record 22 of Set 5 | huanren
# Processing Record 23 of Set 5 | flinders
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | tambopata
# Processing Record 26 of Set 5 | nikolskoye
# Processing Record 27 of Set 5 | tumbagaan
# Processing Record 28 of Set 5 | dubove
# Processing Record 29 of Set 5 | paraiba do sul
# Processing Record 30 of Set 5 | maceio
# Processing Record 31 of Set 5 | wangqing
# Processing Record 32 of Set 5 | zeya
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | gornopravdinsk
# Processing Record 35 of Set 5 | port hawkesbury
# Processing Record 36 of Set 5 | ukiah
# Processing Record 37 of Set 5 | yining
# Processing Record 38 of Set 5 | alekseyevsk
# Processing Record 39 of Set 5 | loandjili
# Processing Record 40 of Set 5 | camacha
# Processing Record 41 of Set 5 | kholodnyy
# Processing Record 42 of Set 5 | torbay
# Processing Record 43 of Set 5 | nioro
# Processing Record 44 of Set 5 | xining
# Processing Record 45 of Set 5 | chuy
# Processing Record 46 of Set 5 | andujar
# Processing Record 47 of Set 5 | mayachnyy
# Processing Record 48 of Set 5 | rudnaya pristan
# Processing Record 49 of Set 5 | pacific grove
# Processing Record 50 of Set 5 | ayan
# Processing Record 1 of Set 6 | severobaykalsk
# Processing Record 2 of Set 6 | mayo
# Processing Record 3 of Set 6 | jackson
# Processing Record 4 of Set 6 | ovre ardal
# Processing Record 5 of Set 6 | jardim
# Processing Record 6 of Set 6 | ust-maya
# Processing Record 7 of Set 6 | saint-philippe
# Processing Record 8 of Set 6 | burnie
# Processing Record 9 of Set 6 | shelburne
# Processing Record 10 of Set 6 | filadelfia
# Processing Record 11 of Set 6 | zhuhai
# Processing Record 12 of Set 6 | chaochou
# City not found. Skipping...
# Processing Record 13 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | marzuq
# Processing Record 16 of Set 6 | grande prairie
# Processing Record 17 of Set 6 | fort saint james
# Processing Record 18 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | yinchuan
# Processing Record 20 of Set 6 | kumano
# Processing Record 21 of Set 6 | harper
# Processing Record 22 of Set 6 | victoria
# Processing Record 23 of Set 6 | perth
# Processing Record 24 of Set 6 | moree
# Processing Record 25 of Set 6 | sola
# Processing Record 26 of Set 6 | micheweni
# Processing Record 27 of Set 6 | fairmont
# Processing Record 28 of Set 6 | aldergrove
# Processing Record 29 of Set 6 | dubti
# Processing Record 30 of Set 6 | viedma
# Processing Record 31 of Set 6 | pagman
# City not found. Skipping...
# Processing Record 32 of Set 6 | kavieng
# Processing Record 33 of Set 6 | ponta delgada
# Processing Record 34 of Set 6 | banjar
# Processing Record 35 of Set 6 | omsukchan
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | imuris
# Processing Record 38 of Set 6 | rodrigues alves
# Processing Record 39 of Set 6 | osypenko
# Processing Record 40 of Set 6 | barrow
# Processing Record 41 of Set 6 | hovd
# Processing Record 42 of Set 6 | lokomotivnyy
# Processing Record 43 of Set 6 | mandera
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | westport
# Processing Record 46 of Set 6 | vila
# Processing Record 47 of Set 6 | veraval
# Processing Record 48 of Set 6 | taunggyi
# Processing Record 49 of Set 6 | buenos aires
# Processing Record 50 of Set 6 | te anau
# Processing Record 1 of Set 7 | nhulunbuy
# Processing Record 2 of Set 7 | nantucket
# Processing Record 3 of Set 7 | sagauli
# Processing Record 4 of Set 7 | gollere
# City not found. Skipping...
# Processing Record 5 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 7 | castro
# Processing Record 7 of Set 7 | umm kaddadah
# Processing Record 8 of Set 7 | trincomalee
# Processing Record 9 of Set 7 | moses lake
# Processing Record 10 of Set 7 | kiama
# Processing Record 11 of Set 7 | asau
# Processing Record 12 of Set 7 | cayenne
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | san jeronimo
# Processing Record 15 of Set 7 | barcelos
# Processing Record 16 of Set 7 | kaseda
# Processing Record 17 of Set 7 | chortomlyk
# Processing Record 18 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 7 | bulgan
# Processing Record 20 of Set 7 | kodiak
# Processing Record 21 of Set 7 | lasa
# Processing Record 22 of Set 7 | sarkand
# Processing Record 23 of Set 7 | miranda
# Processing Record 24 of Set 7 | whitehorse
# Processing Record 25 of Set 7 | hithadhoo
# Processing Record 26 of Set 7 | hervey bay
# Processing Record 27 of Set 7 | nagua
# Processing Record 28 of Set 7 | san patricio
# Processing Record 29 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 7 | kasongo-lunda
# Processing Record 31 of Set 7 | worland
# Processing Record 32 of Set 7 | orlik
# Processing Record 33 of Set 7 | homer
# Processing Record 34 of Set 7 | los llanos de aridane
# Processing Record 35 of Set 7 | kargat
# Processing Record 36 of Set 7 | qui nhon
# Processing Record 37 of Set 7 | chunhuhub
# Processing Record 38 of Set 7 | inhambane
# Processing Record 39 of Set 7 | narsaq
# Processing Record 40 of Set 7 | avera
# Processing Record 41 of Set 7 | horasan
# Processing Record 42 of Set 7 | kaeo
# Processing Record 43 of Set 7 | severo-kurilsk
# Processing Record 44 of Set 7 | chimbote
# Processing Record 45 of Set 7 | merritt island
# Processing Record 46 of Set 7 | nenjiang
# Processing Record 47 of Set 7 | santa marta
# Processing Record 48 of Set 7 | samandag
# Processing Record 49 of Set 7 | port-cartier
# Processing Record 50 of Set 7 | myitkyina
# Processing Record 1 of Set 8 | payson
# Processing Record 2 of Set 8 | palora
# Processing Record 3 of Set 8 | bay city
# Processing Record 4 of Set 8 | college place
# Processing Record 5 of Set 8 | sioux lookout
# Processing Record 6 of Set 8 | esperance
# Processing Record 7 of Set 8 | aykhal
# Processing Record 8 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 8 | flin flon
# Processing Record 10 of Set 8 | manaure
# Processing Record 11 of Set 8 | yuancheng
# Processing Record 12 of Set 8 | nanortalik
# Processing Record 13 of Set 8 | lardos
# Processing Record 14 of Set 8 | tongliao
# Processing Record 15 of Set 8 | vieux-habitants
# Processing Record 16 of Set 8 | dubbo
# Processing Record 17 of Set 8 | batagay-alyta
# Processing Record 18 of Set 8 | faya
# Processing Record 19 of Set 8 | saraipali
# Processing Record 20 of Set 8 | cimarron hills
# Processing Record 21 of Set 8 | batemans bay
# Processing Record 22 of Set 8 | tam ky
# Processing Record 23 of Set 8 | ust-nera
# Processing Record 24 of Set 8 | chumikan
# Processing Record 25 of Set 8 | merauke
# Processing Record 26 of Set 8 | sibolga
# Processing Record 27 of Set 8 | bundaberg
# Processing Record 28 of Set 8 | altamira
# Processing Record 29 of Set 8 | belmonte
# Processing Record 30 of Set 8 | spearfish
# Processing Record 31 of Set 8 | kuminskiy
# Processing Record 32 of Set 8 | bud
# Processing Record 33 of Set 8 | port macquarie
# Processing Record 34 of Set 8 | upington
# Processing Record 35 of Set 8 | naze
# Processing Record 36 of Set 8 | mahibadhoo
# Processing Record 37 of Set 8 | sao geraldo do araguaia
# Processing Record 38 of Set 8 | cabo san lucas
# Processing Record 39 of Set 8 | yar-sale
# Processing Record 40 of Set 8 | beian
# Processing Record 41 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 8 | general bravo
# Processing Record 43 of Set 8 | simbahan
# Processing Record 44 of Set 8 | grand gaube
# Processing Record 45 of Set 8 | juegang
# Processing Record 46 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | kwekwe
# Processing Record 50 of Set 8 | marabba
# Processing Record 1 of Set 9 | qasigiannguit
# Processing Record 2 of Set 9 | sabaudia
# Processing Record 3 of Set 9 | iquique
# Processing Record 4 of Set 9 | impfondo
# Processing Record 5 of Set 9 | san felipe
# Processing Record 6 of Set 9 | iralaya
# Processing Record 7 of Set 9 | banda aceh
# Processing Record 8 of Set 9 | sasovo
# Processing Record 9 of Set 9 | longyearbyen
# Processing Record 10 of Set 9 | ulladulla
# Processing Record 11 of Set 9 | guines
# Processing Record 12 of Set 9 | cabedelo
# Processing Record 13 of Set 9 | greenfield
# Processing Record 14 of Set 9 | ilulissat
# Processing Record 15 of Set 9 | ponte nova
# Processing Record 16 of Set 9 | bay roberts
# Processing Record 17 of Set 9 | baruun-urt
# Processing Record 18 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | vanimo
# Processing Record 20 of Set 9 | port hedland
# Processing Record 21 of Set 9 | puerto madero
# Processing Record 22 of Set 9 | bara
# Processing Record 23 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 9 | lingao
# Processing Record 25 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 9 | azare
# Processing Record 27 of Set 9 | karachi
# Processing Record 28 of Set 9 | hohhot
# Processing Record 29 of Set 9 | bichura
# Processing Record 30 of Set 9 | fez
# Processing Record 31 of Set 9 | makat
# Processing Record 32 of Set 9 | ahipara
# Processing Record 33 of Set 9 | okha
# Processing Record 34 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 9 | manzhouli
# Processing Record 36 of Set 9 | ovsyanka
# Processing Record 37 of Set 9 | balkanabat
# Processing Record 38 of Set 9 | aleppo
# Processing Record 39 of Set 9 | maarianhamina
# Processing Record 40 of Set 9 | komsomolskiy
# Processing Record 41 of Set 9 | hambantota
# Processing Record 42 of Set 9 | morondava
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | misratah
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | lokosovo
# Processing Record 47 of Set 9 | ampanihy
# Processing Record 48 of Set 9 | gayeri
# Processing Record 49 of Set 9 | santa cruz de tenerife
# Processing Record 50 of Set 9 | la palma
# Processing Record 1 of Set 10 | bani
# Processing Record 2 of Set 10 | guarapari
# Processing Record 3 of Set 10 | svetlyy
# Processing Record 4 of Set 10 | bosobolo
# Processing Record 5 of Set 10 | lima
# Processing Record 6 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 10 | mirabad
# Processing Record 8 of Set 10 | miles city
# Processing Record 9 of Set 10 | phonhong
# Processing Record 10 of Set 10 | lufilufi
# Processing Record 11 of Set 10 | guane
# Processing Record 12 of Set 10 | bosaso
# Processing Record 13 of Set 10 | necochea
# Processing Record 14 of Set 10 | bambanglipuro
# Processing Record 15 of Set 10 | coxim
# Processing Record 16 of Set 10 | manokwari
# Processing Record 17 of Set 10 | palmer
# Processing Record 18 of Set 10 | hamina
# Processing Record 19 of Set 10 | new ulm
# Processing Record 20 of Set 10 | monte cristi
# City not found. Skipping...
# Processing Record 21 of Set 10 | prachuap khiri khan
# Processing Record 22 of Set 10 | fukue
# Processing Record 23 of Set 10 | kushiro
# Processing Record 24 of Set 10 | pafos
# Processing Record 25 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 10 | ebenthal
# Processing Record 27 of Set 10 | puerto escondido
# Processing Record 28 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | sivas
# Processing Record 31 of Set 10 | palmdale
# Processing Record 32 of Set 10 | yerbogachen
# Processing Record 33 of Set 10 | pundaguitan
# Processing Record 34 of Set 10 | bilma
# Processing Record 35 of Set 10 | canutama
# Processing Record 36 of Set 10 | zemio
# Processing Record 37 of Set 10 | keuruu
# Processing Record 38 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 39 of Set 10 | brigantine
# Processing Record 40 of Set 10 | verin
# Processing Record 41 of Set 10 | weihai
# Processing Record 42 of Set 10 | canto do buriti
# Processing Record 43 of Set 10 | hastings
# Processing Record 44 of Set 10 | margate
# Processing Record 45 of Set 10 | mao
# Processing Record 46 of Set 10 | lesozavodsk
# Processing Record 47 of Set 10 | kopavogur
# Processing Record 48 of Set 10 | bilibino
# Processing Record 49 of Set 10 | aksu
# Processing Record 50 of Set 10 | bendigo
# Processing Record 1 of Set 11 | farafangana
# Processing Record 2 of Set 11 | nalut
# Processing Record 3 of Set 11 | ranfurly
# Processing Record 4 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 11 | beaumont
# Processing Record 6 of Set 11 | ruwi
# Processing Record 7 of Set 11 | muisne
# Processing Record 8 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 9 of Set 11 | woodward
# Processing Record 10 of Set 11 | altay
# Processing Record 11 of Set 11 | jutai
# Processing Record 12 of Set 11 | ancud
# Processing Record 13 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 14 of Set 11 | comodoro rivadavia
# Processing Record 15 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 11 | galle
# Processing Record 17 of Set 11 | yaan
# Processing Record 18 of Set 11 | shimoda
# Processing Record 19 of Set 11 | gizo
# Processing Record 20 of Set 11 | shenjiamen
# Processing Record 21 of Set 11 | kenai
# Processing Record 22 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 23 of Set 11 | vao
# Processing Record 24 of Set 11 | muros
# Processing Record 25 of Set 11 | ilek
# Processing Record 26 of Set 11 | san quintin
# Processing Record 27 of Set 11 | mulege
# Processing Record 28 of Set 11 | buraydah
# Processing Record 29 of Set 11 | rio gallegos
# Processing Record 30 of Set 11 | shihezi
# Processing Record 31 of Set 11 | atar
# Processing Record 32 of Set 11 | miandrivazo
# Processing Record 33 of Set 11 | bathsheba
# Processing Record 34 of Set 11 | sao luiz gonzaga
# Processing Record 35 of Set 11 | burns lake
# Processing Record 36 of Set 11 | kupang
# Processing Record 37 of Set 11 | antri
# Processing Record 38 of Set 11 | valparaiso
# Processing Record 39 of Set 11 | goure
# Processing Record 40 of Set 11 | cabra
# Processing Record 41 of Set 11 | hamtic
# Processing Record 42 of Set 11 | tiarei
# Processing Record 43 of Set 11 | vardo
# Processing Record 44 of Set 11 | chom bung
# City not found. Skipping...
# Processing Record 45 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 46 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 11 | novobirilyussy
# Processing Record 48 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 11 | tautira
# Processing Record 50 of Set 11 | svetlaya
# Processing Record 1 of Set 12 | manama
# Processing Record 2 of Set 12 | samarai
# Processing Record 3 of Set 12 | assiniboia
# Processing Record 4 of Set 12 | hami
# Processing Record 5 of Set 12 | damietta
# Processing Record 6 of Set 12 | himora
# City not found. Skipping...
# Processing Record 7 of Set 12 | shetpe
# Processing Record 8 of Set 12 | tanete
# Processing Record 9 of Set 12 | roma
# Processing Record 10 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 12 | naberera
# Processing Record 12 of Set 12 | vigrestad
# Processing Record 13 of Set 12 | chernyshevskiy
# Processing Record 14 of Set 12 | lakefield
# Processing Record 15 of Set 12 | laguna
# Processing Record 16 of Set 12 | khartoum
# Processing Record 17 of Set 12 | poltava
# Processing Record 18 of Set 12 | itarema
# Processing Record 19 of Set 12 | benguela
# Processing Record 20 of Set 12 | alice springs
# Processing Record 21 of Set 12 | upata
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | sale
# Processing Record 24 of Set 12 | liaozhong
# Processing Record 25 of Set 12 | arvika
# Processing Record 26 of Set 12 | riyadh
# Processing Record 27 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 12 | sobolevo
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | tres arroyos
# Processing Record 31 of Set 12 | sistranda
# Processing Record 32 of Set 12 | asmara
# Processing Record 33 of Set 12 | kolyshley
# Processing Record 34 of Set 12 | san carlos de bariloche
# Processing Record 35 of Set 12 | borovoy
# Processing Record 36 of Set 12 | tabuleiro do norte
# Processing Record 37 of Set 12 | lerik
# Processing Record 38 of Set 12 | saint-denis
# Processing Record 39 of Set 12 | nyzhnya duvanka
# Processing Record 40 of Set 12 | san nicolas
# Processing Record 41 of Set 12 | san juan
# Processing Record 42 of Set 12 | grindavik
# Processing Record 43 of Set 12 | mecca
# Processing Record 44 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 45 of Set 12 | north platte
# Processing Record 46 of Set 12 | gijon
# Processing Record 47 of Set 12 | hofn
# Processing Record 48 of Set 12 | chandia
# Processing Record 49 of Set 12 | huanan
# Processing Record 50 of Set 12 | cartagena
# Processing Record 1 of Set 13 | los andes
# Processing Record 2 of Set 13 | taltal
# Processing Record 3 of Set 13 | bandarbeyla
# Processing Record 4 of Set 13 | rio claro
# Processing Record 5 of Set 13 | ketchikan
# Processing Record 6 of Set 13 | jaru
# Processing Record 7 of Set 13 | menongue
# Processing Record 8 of Set 13 | leningradskiy
# Processing Record 9 of Set 13 | waitati
# Processing Record 10 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 13 | cockburn town
# Processing Record 12 of Set 13 | oriximina
# Processing Record 13 of Set 13 | morro da fumaca
# Processing Record 14 of Set 13 | yeehaw junction
# City not found. Skipping...
# Processing Record 15 of Set 13 | medicine hat
# Processing Record 16 of Set 13 | dalhousie
# Processing Record 17 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 18 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 13 | tazovskiy
# Processing Record 20 of Set 13 | jacareacanga
# Processing Record 21 of Set 13 | pierre
# Processing Record 22 of Set 13 | krasnoselkup
# Processing Record 23 of Set 13 | champerico
# Processing Record 24 of Set 13 | thinadhoo
# Processing Record 25 of Set 13 | sosnovka
# Processing Record 26 of Set 13 | goroka
# Processing Record 27 of Set 13 | houma
# Processing Record 28 of Set 13 | goycay
# City not found. Skipping...
# Processing Record 29 of Set 13 | kalmunai
# Processing Record 30 of Set 13 | adrar
# Processing Record 31 of Set 13 | dolzhanskaya
# Processing Record 32 of Set 13 | coolum beach
# Processing Record 33 of Set 13 | akdepe
# Processing Record 34 of Set 13 | thano bula khan
# City not found. Skipping...
# Processing Record 35 of Set 13 | srednekolymsk
# Processing Record 36 of Set 13 | puerto guzman
# Processing Record 37 of Set 13 | nioaque
# Processing Record 38 of Set 13 | santiago del estero
# Processing Record 39 of Set 13 | mitchell
# Processing Record 40 of Set 13 | huilong
# Processing Record 41 of Set 13 | mezen
# Processing Record 42 of Set 13 | boddam
# Processing Record 43 of Set 13 | saint-georges
# Processing Record 44 of Set 13 | barcelona
# Processing Record 45 of Set 13 | batticaloa
# Processing Record 46 of Set 13 | loreto
# Processing Record 47 of Set 13 | kabalo
# Processing Record 48 of Set 13 | mukdahan
# Processing Record 49 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 13 | kailua
# Processing Record 1 of Set 14 | kashkhatau
# Processing Record 2 of Set 14 | gushikawa
# Processing Record 3 of Set 14 | ixtapa
# Processing Record 4 of Set 14 | mincivan
# Processing Record 5 of Set 14 | derzhavinsk
# Processing Record 6 of Set 14 | kijang
# Processing Record 7 of Set 14 | esso
# Processing Record 8 of Set 14 | tanabe
# Processing Record 9 of Set 14 | ust-ilimsk
# Processing Record 10 of Set 14 | kefamenanu
# Processing Record 11 of Set 14 | beringovskiy
# Processing Record 12 of Set 14 | dunedin
# Processing Record 13 of Set 14 | keetmanshoop
# Processing Record 14 of Set 14 | tiruvottiyur
# City not found. Skipping...
# Processing Record 15 of Set 14 | glenwood springs
# Processing Record 16 of Set 14 | sur
# Processing Record 17 of Set 14 | soe
# Processing Record 18 of Set 14 | barroquinha
# Processing Record 19 of Set 14 | xai-xai
# Processing Record 20 of Set 14 | kandy
# Processing Record 21 of Set 14 | lorengau
# Processing Record 22 of Set 14 | vila franca do campo
# Processing Record 23 of Set 14 | nishihara
# Processing Record 24 of Set 14 | waingapu
# Processing Record 25 of Set 14 | codrington
# Processing Record 26 of Set 14 | soyo
# Processing Record 27 of Set 14 | killybegs
# Processing Record 28 of Set 14 | cap malheureux
# Processing Record 29 of Set 14 | araci
# Processing Record 30 of Set 14 | tateyama
# Processing Record 31 of Set 14 | toktogul
# Processing Record 32 of Set 14 | guerrero negro
# Processing Record 33 of Set 14 | scarborough
# Processing Record 34 of Set 14 | turukhansk
# Processing Record 35 of Set 14 | wadena
# Processing Record 36 of Set 14 | shiyan
# Processing Record 37 of Set 14 | kayes
# Processing Record 38 of Set 14 | lavrentiya
# Processing Record 39 of Set 14 | tigzirt
# Processing Record 40 of Set 14 | alyangula
# Processing Record 41 of Set 14 | urumqi
# Processing Record 42 of Set 14 | fuengirola
# Processing Record 43 of Set 14 | tansen
# Processing Record 44 of Set 14 | alofi
# Processing Record 45 of Set 14 | finnsnes
# Processing Record 46 of Set 14 | mpwapwa
# Processing Record 47 of Set 14 | bako
# Processing Record 48 of Set 14 | ploemeur
# Processing Record 49 of Set 14 | minot
# Processing Record 50 of Set 14 | castle rock
# Processing Record 1 of Set 15 | opuwo
# Processing Record 2 of Set 15 | mananjary
# Processing Record 3 of Set 15 | arrecife
# Processing Record 4 of Set 15 | souillac
# Processing Record 5 of Set 15 | butembo
# Processing Record 6 of Set 15 | belaya gora
# Processing Record 7 of Set 15 | abhar
# Processing Record 8 of Set 15 | gasa
# Processing Record 9 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 10 of Set 15 | desbiens
# Processing Record 11 of Set 15 | manubah
# City not found. Skipping...
# Processing Record 12 of Set 15 | marawi
# Processing Record 13 of Set 15 | lashio
# Processing Record 14 of Set 15 | maneadero
# Processing Record 15 of Set 15 | mount gambier
# Processing Record 16 of Set 15 | maicao
# Processing Record 17 of Set 15 | anzio
# Processing Record 18 of Set 15 | sterling
# Processing Record 19 of Set 15 | ladario
# Processing Record 20 of Set 15 | rock sound
# Processing Record 21 of Set 15 | zhigansk
# Processing Record 22 of Set 15 | jaque
# Processing Record 23 of Set 15 | montague
# Processing Record 24 of Set 15 | saint-francois
# Processing Record 25 of Set 15 | grao mogol
# Processing Record 26 of Set 15 | paracuru
# Processing Record 27 of Set 15 | porbandar
# Processing Record 28 of Set 15 | fayaoue
# Processing Record 29 of Set 15 | mandalgovi
# Processing Record 30 of Set 15 | killarney
# Processing Record 31 of Set 15 | galesong
# Processing Record 32 of Set 15 | serenje
# Processing Record 33 of Set 15 | sidhi
# Processing Record 34 of Set 15 | mazagao
# Processing Record 35 of Set 15 | alappuzha
# Processing Record 36 of Set 15 | bonavista
# Processing Record 37 of Set 15 | kingaroy
# Processing Record 38 of Set 15 | mount isa
# Processing Record 39 of Set 15 | mitu
# Processing Record 40 of Set 15 | sao miguel do araguaia
# Processing Record 41 of Set 15 | novyy buh
# Processing Record 42 of Set 15 | biltine
# Processing Record 43 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 15 | senador jose porfirio
# Processing Record 45 of Set 15 | wang saphung
# Processing Record 46 of Set 15 | balakhta
# Processing Record 47 of Set 15 | honggang
# Processing Record 48 of Set 15 | quatre cocos
# Processing Record 49 of Set 15 | samana
# Processing Record 50 of Set 15 | tefe
# Processing Record 1 of Set 16 | alindao
# Processing Record 2 of Set 16 | gwembe
# Processing Record 3 of Set 16 | manadhoo
# Processing Record 4 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 16 | astipalaia
# City not found. Skipping...
# Processing Record 6 of Set 16 | henties bay
# Processing Record 7 of Set 16 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 16 | staryy krym
# Processing Record 9 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 16 | hirara
# Processing Record 11 of Set 16 | samalaeulu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Buchanan      LR   5.8808  -10.0467     87.80        70          75
# 1  Clyde River      CA  70.4692  -68.5914    -11.20        77           1
# 2       Touros      BR  -5.1989  -35.4608     87.80        51          20
# 3     Freetown      SL   8.4840  -13.2299     87.80        58           0
# 4       Faanui      PF -16.4833 -151.7500     80.92        66          38
# 5   Vila Velha      BR -20.3297  -40.2925     90.00        58          20
# 6     Kamaishi      JP  39.2667  141.8833     27.73        90          47
# 7    Upernavik      GL  72.7868  -56.1549     -9.06        80          30
# 8      Rikitea      PF -23.1203 -134.9692     79.12        69          80
# 9      Gogrial      SS   8.5332   28.1004     85.89        14          11
#
#    Wind Speed Current Description
# 0        8.05          light rain
# 1        2.30           clear sky
# 2       13.80          few clouds
# 3        9.22                haze
# 4        7.27    scattered clouds
# 5       18.41          few clouds
# 6       22.82          light snow
# 7       12.01    scattered clouds
# 8        4.76          light rain
# 9        4.09          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
