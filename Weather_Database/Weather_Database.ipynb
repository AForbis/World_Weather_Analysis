# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

   # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherDescription = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weatherDescription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | launceston
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | tadine
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | raga
# Processing Record 13 of Set 1 | tjome
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | arman
# Processing Record 16 of Set 1 | puerto suarez
# Processing Record 17 of Set 1 | isangel
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | arraial do cabo
# Processing Record 20 of Set 1 | uchiza
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | port alfred
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | narsaq
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | san pedro de macoris
# Processing Record 32 of Set 1 | kijang
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | komsomolskiy
# Processing Record 39 of Set 1 | vila franca do campo
# Processing Record 40 of Set 1 | provideniya
# Processing Record 41 of Set 1 | gohpur
# Processing Record 42 of Set 1 | hetauda
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | shimoda
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | cidreira
# Processing Record 47 of Set 1 | katsina
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 1 | dawlatabad
# Processing Record 1 of Set 2 | inhambane
# Processing Record 2 of Set 2 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 2 | dipkarpaz
# City not found. Skipping...
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | socorro
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | zhigansk
# Processing Record 10 of Set 2 | tuy hoa
# Processing Record 11 of Set 2 | umm lajj
# Processing Record 12 of Set 2 | lasa
# Processing Record 13 of Set 2 | matamoros
# Processing Record 14 of Set 2 | klaksvik
# Processing Record 15 of Set 2 | butaritari
# Processing Record 16 of Set 2 | verrettes
# Processing Record 17 of Set 2 | vila velha
# Processing Record 18 of Set 2 | puerto colombia
# Processing Record 19 of Set 2 | quelimane
# Processing Record 20 of Set 2 | salalah
# Processing Record 21 of Set 2 | poum
# Processing Record 22 of Set 2 | ocampo
# Processing Record 23 of Set 2 | cherskiy
# Processing Record 24 of Set 2 | sabha
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | uttarkashi
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | tabas
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | saint-francois
# Processing Record 31 of Set 2 | husavik
# Processing Record 32 of Set 2 | codrington
# Processing Record 33 of Set 2 | genhe
# Processing Record 34 of Set 2 | bandarbeyla
# Processing Record 35 of Set 2 | bamora
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | saint george
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | beringovskiy
# Processing Record 40 of Set 2 | kamsack
# Processing Record 41 of Set 2 | palana
# Processing Record 42 of Set 2 | mehamn
# Processing Record 43 of Set 2 | kirovohrad
# Processing Record 44 of Set 2 | masunga
# Processing Record 45 of Set 2 | gleisdorf
# Processing Record 46 of Set 2 | kostenec
# City not found. Skipping...
# Processing Record 47 of Set 2 | danjiangkou
# Processing Record 48 of Set 2 | kudahuvadhoo
# Processing Record 49 of Set 2 | itaituba
# Processing Record 50 of Set 2 | moerai
# Processing Record 1 of Set 3 | fort nelson
# Processing Record 2 of Set 3 | san patricio
# Processing Record 3 of Set 3 | airai
# Processing Record 4 of Set 3 | yar-sale
# Processing Record 5 of Set 3 | omsukchan
# Processing Record 6 of Set 3 | qaanaaq
# Processing Record 7 of Set 3 | chuy
# Processing Record 8 of Set 3 | tanete
# Processing Record 9 of Set 3 | katiola
# Processing Record 10 of Set 3 | sinnamary
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | haines junction
# Processing Record 13 of Set 3 | cap-aux-meules
# Processing Record 14 of Set 3 | smithers
# Processing Record 15 of Set 3 | fortuna
# Processing Record 16 of Set 3 | mandal
# Processing Record 17 of Set 3 | port elizabeth
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | pedernales
# Processing Record 20 of Set 3 | batemans bay
# Processing Record 21 of Set 3 | durango
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | brodick
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | tulsipur
# Processing Record 28 of Set 3 | mimongo
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | los llanos de aridane
# Processing Record 31 of Set 3 | mogadishu
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | mount isa
# Processing Record 34 of Set 3 | viytivka
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | cape town
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | chapais
# Processing Record 42 of Set 3 | burica
# City not found. Skipping...
# Processing Record 43 of Set 3 | taoudenni
# Processing Record 44 of Set 3 | morehead
# Processing Record 45 of Set 3 | yinchuan
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | vagay
# Processing Record 48 of Set 3 | caraballeda
# Processing Record 49 of Set 3 | kemptville
# Processing Record 50 of Set 3 | vardo
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | dombas
# Processing Record 3 of Set 4 | mandalgovi
# Processing Record 4 of Set 4 | ibra
# Processing Record 5 of Set 4 | yanam
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | mount gambier
# Processing Record 9 of Set 4 | nara
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | igarka
# Processing Record 12 of Set 4 | valparaiso
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 4 | hohhot
# Processing Record 16 of Set 4 | karamay
# City not found. Skipping...
# Processing Record 17 of Set 4 | lishu
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | vung tau
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | san joaquin
# Processing Record 24 of Set 4 | general roca
# Processing Record 25 of Set 4 | verkh-usugli
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | iberia
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | galveston
# Processing Record 30 of Set 4 | hualmay
# Processing Record 31 of Set 4 | port hedland
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | krasnogvardeyskoye
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | seoul
# Processing Record 36 of Set 4 | namibe
# Processing Record 37 of Set 4 | porto nacional
# Processing Record 38 of Set 4 | aklavik
# Processing Record 39 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 4 | padang
# Processing Record 41 of Set 4 | hwange
# Processing Record 42 of Set 4 | gnjilane
# Processing Record 43 of Set 4 | nuevitas
# Processing Record 44 of Set 4 | kampong thum
# Processing Record 45 of Set 4 | chumikan
# Processing Record 46 of Set 4 | souillac
# Processing Record 47 of Set 4 | fairbanks
# Processing Record 48 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 4 | hrodna
# Processing Record 50 of Set 4 | kathmandu
# Processing Record 1 of Set 5 | kamensk-uralskiy
# Processing Record 2 of Set 5 | mildura
# Processing Record 3 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 5 | adrar
# Processing Record 5 of Set 5 | mednogorsk
# Processing Record 6 of Set 5 | eaton socon
# Processing Record 7 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 5 | neryungri
# Processing Record 9 of Set 5 | lixourion
# Processing Record 10 of Set 5 | ocotal
# Processing Record 11 of Set 5 | betanzos
# Processing Record 12 of Set 5 | vorukh
# Processing Record 13 of Set 5 | abatskoye
# Processing Record 14 of Set 5 | havoysund
# Processing Record 15 of Set 5 | muscat
# Processing Record 16 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 17 of Set 5 | camacha
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | lorengau
# Processing Record 20 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 5 | ogbomosho
# Processing Record 22 of Set 5 | porto walter
# Processing Record 23 of Set 5 | nuoro
# Processing Record 24 of Set 5 | san francisco
# Processing Record 25 of Set 5 | mar del plata
# Processing Record 26 of Set 5 | ostrovnoy
# Processing Record 27 of Set 5 | ahipara
# Processing Record 28 of Set 5 | tabou
# Processing Record 29 of Set 5 | ammon
# Processing Record 30 of Set 5 | mayor pablo lagerenza
# Processing Record 31 of Set 5 | loiza
# Processing Record 32 of Set 5 | gaogou
# Processing Record 33 of Set 5 | karaj
# Processing Record 34 of Set 5 | luderitz
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | westerland
# Processing Record 37 of Set 5 | havre-saint-pierre
# Processing Record 38 of Set 5 | ust-kuyga
# Processing Record 39 of Set 5 | darhan
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | bilma
# Processing Record 42 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 5 | coihaique
# Processing Record 44 of Set 5 | arvika
# Processing Record 45 of Set 5 | college
# Processing Record 46 of Set 5 | wanaka
# Processing Record 47 of Set 5 | tasiilaq
# Processing Record 48 of Set 5 | pangkalanbuun
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | killybegs
# Processing Record 1 of Set 6 | saint-philippe
# Processing Record 2 of Set 6 | marquelia
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | mana
# Processing Record 5 of Set 6 | grants
# Processing Record 6 of Set 6 | kautokeino
# Processing Record 7 of Set 6 | juegang
# Processing Record 8 of Set 6 | constitucion
# Processing Record 9 of Set 6 | honningsvag
# Processing Record 10 of Set 6 | karasjok
# Processing Record 11 of Set 6 | panzhihua
# Processing Record 12 of Set 6 | norre alslev
# Processing Record 13 of Set 6 | pimentel
# Processing Record 14 of Set 6 | umba
# Processing Record 15 of Set 6 | chokurdakh
# Processing Record 16 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 17 of Set 6 | bethel
# Processing Record 18 of Set 6 | hami
# Processing Record 19 of Set 6 | bow island
# Processing Record 20 of Set 6 | santa maria da boa vista
# Processing Record 21 of Set 6 | esmeralda
# Processing Record 22 of Set 6 | cayenne
# Processing Record 23 of Set 6 | princeton
# Processing Record 24 of Set 6 | bilibino
# Processing Record 25 of Set 6 | esna
# Processing Record 26 of Set 6 | palamuse
# Processing Record 27 of Set 6 | kedrovyy
# Processing Record 28 of Set 6 | iqaluit
# Processing Record 29 of Set 6 | gwanda
# Processing Record 30 of Set 6 | mulege
# Processing Record 31 of Set 6 | ranot
# Processing Record 32 of Set 6 | saldanha
# Processing Record 33 of Set 6 | sipoo
# Processing Record 34 of Set 6 | shegaon
# Processing Record 35 of Set 6 | turayf
# Processing Record 36 of Set 6 | tura
# Processing Record 37 of Set 6 | san gregorio
# Processing Record 38 of Set 6 | cody
# Processing Record 39 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 6 | oyugis
# Processing Record 41 of Set 6 | spokane
# Processing Record 42 of Set 6 | chota
# Processing Record 43 of Set 6 | brumadinho
# Processing Record 44 of Set 6 | pauini
# Processing Record 45 of Set 6 | alice town
# Processing Record 46 of Set 6 | kontagora
# Processing Record 47 of Set 6 | ossora
# Processing Record 48 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | port lincoln
# Processing Record 1 of Set 7 | boa esperanca
# Processing Record 2 of Set 7 | waipawa
# Processing Record 3 of Set 7 | tuktoyaktuk
# Processing Record 4 of Set 7 | taltal
# Processing Record 5 of Set 7 | vostok
# Processing Record 6 of Set 7 | kulhudhuffushi
# Processing Record 7 of Set 7 | olinda
# Processing Record 8 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 7 | teya
# Processing Record 10 of Set 7 | aurangabad
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | doha
# Processing Record 15 of Set 7 | thompson
# Processing Record 16 of Set 7 | port macquarie
# Processing Record 17 of Set 7 | comodoro rivadavia
# Processing Record 18 of Set 7 | longyearbyen
# Processing Record 19 of Set 7 | sisimiut
# Processing Record 20 of Set 7 | pathein
# Processing Record 21 of Set 7 | chorbog
# City not found. Skipping...
# Processing Record 22 of Set 7 | kavaratti
# Processing Record 23 of Set 7 | matagami
# Processing Record 24 of Set 7 | pyaozerskiy
# Processing Record 25 of Set 7 | plouzane
# Processing Record 26 of Set 7 | balabac
# Processing Record 27 of Set 7 | charters towers
# Processing Record 28 of Set 7 | kavieng
# Processing Record 29 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 7 | mocuba
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | pisco
# Processing Record 33 of Set 7 | izazi
# Processing Record 34 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 7 | eureka
# Processing Record 36 of Set 7 | kuryk
# Processing Record 37 of Set 7 | iranshahr
# Processing Record 38 of Set 7 | skibbereen
# Processing Record 39 of Set 7 | portland
# Processing Record 40 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 7 | oktyabrskiy
# Processing Record 42 of Set 7 | pedasi
# Processing Record 43 of Set 7 | mangan
# Processing Record 44 of Set 7 | jishou
# Processing Record 45 of Set 7 | vestmanna
# Processing Record 46 of Set 7 | chicama
# Processing Record 47 of Set 7 | tessalit
# Processing Record 48 of Set 7 | ivybridge
# Processing Record 49 of Set 7 | kipushi
# Processing Record 50 of Set 7 | irondequoit
# Processing Record 1 of Set 8 | tigil
# Processing Record 2 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 8 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 4 of Set 8 | cootamundra
# Processing Record 5 of Set 8 | sansai
# City not found. Skipping...
# Processing Record 6 of Set 8 | byron bay
# Processing Record 7 of Set 8 | mindelo
# Processing Record 8 of Set 8 | moron
# Processing Record 9 of Set 8 | oistins
# Processing Record 10 of Set 8 | lompoc
# Processing Record 11 of Set 8 | sitka
# Processing Record 12 of Set 8 | russellville
# Processing Record 13 of Set 8 | sangar
# Processing Record 14 of Set 8 | paita
# Processing Record 15 of Set 8 | djibo
# Processing Record 16 of Set 8 | dwarka
# Processing Record 17 of Set 8 | skelleftea
# Processing Record 18 of Set 8 | abomey
# Processing Record 19 of Set 8 | kinkala
# Processing Record 20 of Set 8 | muisne
# Processing Record 21 of Set 8 | vallenar
# Processing Record 22 of Set 8 | mangrol
# Processing Record 23 of Set 8 | yatsuo
# Processing Record 24 of Set 8 | mao
# Processing Record 25 of Set 8 | hambantota
# Processing Record 26 of Set 8 | rock sound
# Processing Record 27 of Set 8 | pochutla
# Processing Record 28 of Set 8 | nanortalik
# Processing Record 29 of Set 8 | gigmoto
# Processing Record 30 of Set 8 | cairns
# Processing Record 31 of Set 8 | tiruppuvanam
# Processing Record 32 of Set 8 | san andres
# Processing Record 33 of Set 8 | lanigan
# Processing Record 34 of Set 8 | consolacion del sur
# Processing Record 35 of Set 8 | san juan
# Processing Record 36 of Set 8 | didao
# Processing Record 37 of Set 8 | floro
# Processing Record 38 of Set 8 | zapolyarnyy
# Processing Record 39 of Set 8 | nelson bay
# Processing Record 40 of Set 8 | mayya
# Processing Record 41 of Set 8 | berlevag
# Processing Record 42 of Set 8 | chernyshevskiy
# Processing Record 43 of Set 8 | faanui
# Processing Record 44 of Set 8 | corrente
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | ponta delgada
# Processing Record 47 of Set 8 | san cristobal
# Processing Record 48 of Set 8 | hervey bay
# Processing Record 49 of Set 8 | ajaccio
# Processing Record 50 of Set 8 | arlit
# Processing Record 1 of Set 9 | santa isabel do rio negro
# Processing Record 2 of Set 9 | zyryanka
# Processing Record 3 of Set 9 | ozernovskiy
# Processing Record 4 of Set 9 | viana
# Processing Record 5 of Set 9 | billings
# Processing Record 6 of Set 9 | aksu
# Processing Record 7 of Set 9 | turukhansk
# Processing Record 8 of Set 9 | derbent
# Processing Record 9 of Set 9 | la montanita
# Processing Record 10 of Set 9 | varkkallai
# Processing Record 11 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 9 | naze
# Processing Record 13 of Set 9 | shimanovsk
# Processing Record 14 of Set 9 | san policarpo
# Processing Record 15 of Set 9 | los algarrobos
# Processing Record 16 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | talaya
# Processing Record 18 of Set 9 | khani
# Processing Record 19 of Set 9 | anloga
# Processing Record 20 of Set 9 | nantucket
# Processing Record 21 of Set 9 | knysna
# Processing Record 22 of Set 9 | vaitape
# Processing Record 23 of Set 9 | shingu
# Processing Record 24 of Set 9 | never
# Processing Record 25 of Set 9 | areka
# Processing Record 26 of Set 9 | farafangana
# Processing Record 27 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 28 of Set 9 | areia branca
# Processing Record 29 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 30 of Set 9 | baruun-urt
# Processing Record 31 of Set 9 | itaueira
# Processing Record 32 of Set 9 | cabo rojo
# Processing Record 33 of Set 9 | omboue
# Processing Record 34 of Set 9 | kinshasa
# Processing Record 35 of Set 9 | flinders
# Processing Record 36 of Set 9 | melville
# Processing Record 37 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 38 of Set 9 | bojnurd
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | trenggalek
# Processing Record 41 of Set 9 | jalu
# Processing Record 42 of Set 9 | port blair
# Processing Record 43 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 44 of Set 9 | dongsheng
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | berberati
# Processing Record 47 of Set 9 | biltine
# Processing Record 48 of Set 9 | altay
# Processing Record 49 of Set 9 | roblin
# Processing Record 50 of Set 9 | morki
# Processing Record 1 of Set 10 | bairiki
# Processing Record 2 of Set 10 | nabire
# Processing Record 3 of Set 10 | whitehorse
# Processing Record 4 of Set 10 | praia
# Processing Record 5 of Set 10 | bull savanna
# Processing Record 6 of Set 10 | coquimbo
# Processing Record 7 of Set 10 | puerto escondido
# Processing Record 8 of Set 10 | quatre cocos
# Processing Record 9 of Set 10 | luwingu
# Processing Record 10 of Set 10 | bara
# Processing Record 11 of Set 10 | gamba
# Processing Record 12 of Set 10 | media luna
# Processing Record 13 of Set 10 | nemuro
# Processing Record 14 of Set 10 | dagana
# Processing Record 15 of Set 10 | qingquan
# Processing Record 16 of Set 10 | atar
# Processing Record 17 of Set 10 | belmonte
# Processing Record 18 of Set 10 | dingle
# Processing Record 19 of Set 10 | rock springs
# Processing Record 20 of Set 10 | saint simons
# Processing Record 21 of Set 10 | mwinilunga
# Processing Record 22 of Set 10 | broome
# Processing Record 23 of Set 10 | pombas
# Processing Record 24 of Set 10 | moroni
# Processing Record 25 of Set 10 | bereda
# Processing Record 26 of Set 10 | alyangula
# Processing Record 27 of Set 10 | laxou
# Processing Record 28 of Set 10 | kahului
# Processing Record 29 of Set 10 | camara de lobos
# Processing Record 30 of Set 10 | narasannapeta
# Processing Record 31 of Set 10 | dera bugti
# Processing Record 32 of Set 10 | montrose
# Processing Record 33 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 10 | moose factory
# Processing Record 35 of Set 10 | trelew
# Processing Record 36 of Set 10 | salaga
# Processing Record 37 of Set 10 | syumsi
# Processing Record 38 of Set 10 | usman
# Processing Record 39 of Set 10 | aitape
# Processing Record 40 of Set 10 | urengoy
# Processing Record 41 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 10 | broken hill
# Processing Record 43 of Set 10 | cockburn town
# Processing Record 44 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | jiaohe
# Processing Record 47 of Set 10 | diamantino
# Processing Record 48 of Set 10 | lazaro cardenas
# Processing Record 49 of Set 10 | mujiayingzi
# Processing Record 50 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 11 | athabasca
# Processing Record 2 of Set 11 | kamenka
# Processing Record 3 of Set 11 | inirida
# Processing Record 4 of Set 11 | la asuncion
# Processing Record 5 of Set 11 | lanzhou
# Processing Record 6 of Set 11 | la rioja
# Processing Record 7 of Set 11 | xichang
# Processing Record 8 of Set 11 | ixtapa
# Processing Record 9 of Set 11 | kaffrine
# Processing Record 10 of Set 11 | tubuala
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | hayvoron
# Processing Record 13 of Set 11 | neyshabur
# Processing Record 14 of Set 11 | karaton
# Processing Record 15 of Set 11 | rosario
# Processing Record 16 of Set 11 | fujin
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | aire-sur-la-lys
# Processing Record 19 of Set 11 | sicamous
# Processing Record 20 of Set 11 | marawi
# Processing Record 21 of Set 11 | kuldur
# Processing Record 22 of Set 11 | sabirabad
# Processing Record 23 of Set 11 | gilching
# Processing Record 24 of Set 11 | dhidhdhoo
# Processing Record 25 of Set 11 | ribnica
# Processing Record 26 of Set 11 | dingzhou
# Processing Record 27 of Set 11 | chokwe
# Processing Record 28 of Set 11 | preeceville
# Processing Record 29 of Set 11 | te anau
# Processing Record 30 of Set 11 | requena
# Processing Record 31 of Set 11 | asau
# Processing Record 32 of Set 11 | cap malheureux
# Processing Record 33 of Set 11 | curup
# Processing Record 34 of Set 11 | singaparna
# Processing Record 35 of Set 11 | saint-georges
# Processing Record 36 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 37 of Set 11 | bathsheba
# Processing Record 38 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 39 of Set 11 | khash
# Processing Record 40 of Set 11 | harindanga
# Processing Record 41 of Set 11 | gambela
# Processing Record 42 of Set 11 | verkhnetulomskiy
# Processing Record 43 of Set 11 | smidovich
# Processing Record 44 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 45 of Set 11 | alugan
# Processing Record 46 of Set 11 | batticaloa
# Processing Record 47 of Set 11 | urumqi
# Processing Record 48 of Set 11 | general pico
# Processing Record 49 of Set 11 | la ronge
# Processing Record 50 of Set 11 | sibiti
# Processing Record 1 of Set 12 | caconda
# Processing Record 2 of Set 12 | perth
# Processing Record 3 of Set 12 | buala
# Processing Record 4 of Set 12 | bosaso
# Processing Record 5 of Set 12 | guadalupe y calvo
# Processing Record 6 of Set 12 | tazovskiy
# Processing Record 7 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 8 of Set 12 | zhob
# Processing Record 9 of Set 12 | dunedin
# Processing Record 10 of Set 12 | jining
# Processing Record 11 of Set 12 | coahuayana
# Processing Record 12 of Set 12 | alta gracia
# Processing Record 13 of Set 12 | uglegorsk
# Processing Record 14 of Set 12 | makat
# Processing Record 15 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 16 of Set 12 | banes
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | mineiros
# Processing Record 19 of Set 12 | otane
# Processing Record 20 of Set 12 | esperance
# Processing Record 21 of Set 12 | kloulklubed
# Processing Record 22 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 23 of Set 12 | ubrique
# Processing Record 24 of Set 12 | san rafael
# Processing Record 25 of Set 12 | yulara
# Processing Record 26 of Set 12 | sawasawa
# City not found. Skipping...
# Processing Record 27 of Set 12 | masterton
# Processing Record 28 of Set 12 | kungurtug
# Processing Record 29 of Set 12 | alta floresta
# Processing Record 30 of Set 12 | somvarpet
# Processing Record 31 of Set 12 | sai buri
# Processing Record 32 of Set 12 | buqayq
# City not found. Skipping...
# Processing Record 33 of Set 12 | nalut
# Processing Record 34 of Set 12 | pinawa
# Processing Record 35 of Set 12 | tiznit
# Processing Record 36 of Set 12 | lisala
# Processing Record 37 of Set 12 | bintulu
# Processing Record 38 of Set 12 | grand baie
# Processing Record 39 of Set 12 | murmashi
# Processing Record 40 of Set 12 | porto novo
# Processing Record 41 of Set 12 | bhadrachalam
# Processing Record 42 of Set 12 | aginskoye
# Processing Record 43 of Set 12 | bonavista
# Processing Record 44 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 12 | abu dhabi
# Processing Record 46 of Set 12 | zetel
# Processing Record 47 of Set 12 | mabaruma
# Processing Record 48 of Set 12 | chivay
# Processing Record 49 of Set 12 | general bravo
# Processing Record 50 of Set 12 | bubaque
# Processing Record 1 of Set 13 | yining
# Processing Record 2 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 3 of Set 13 | bundaberg
# Processing Record 4 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 13 | berdorf
# Processing Record 6 of Set 13 | quang ngai
# Processing Record 7 of Set 13 | laja
# Processing Record 8 of Set 13 | zima
# Processing Record 9 of Set 13 | ternate
# Processing Record 10 of Set 13 | bitkine
# Processing Record 11 of Set 13 | northam
# Processing Record 12 of Set 13 | abashiri
# Processing Record 13 of Set 13 | jieshi
# Processing Record 14 of Set 13 | sakakah
# Processing Record 15 of Set 13 | kama
# Processing Record 16 of Set 13 | egvekinot
# Processing Record 17 of Set 13 | talnakh
# Processing Record 18 of Set 13 | mitsamiouli
# Processing Record 19 of Set 13 | noumea
# Processing Record 20 of Set 13 | najran
# Processing Record 21 of Set 13 | sao felix do xingu
# Processing Record 22 of Set 13 | santa maria
# Processing Record 23 of Set 13 | kendari
# Processing Record 24 of Set 13 | aparecida do taboado
# Processing Record 25 of Set 13 | tatarskaya pishlya
# Processing Record 26 of Set 13 | berea
# Processing Record 27 of Set 13 | zlotow
# Processing Record 28 of Set 13 | sragen
# Processing Record 29 of Set 13 | huilong
# Processing Record 30 of Set 13 | aljezur
# Processing Record 31 of Set 13 | tirlyanskiy
# Processing Record 32 of Set 13 | shakiso
# Processing Record 33 of Set 13 | dzhebariki-khaya
# Processing Record 34 of Set 13 | araceli
# Processing Record 35 of Set 13 | vestmannaeyjar
# Processing Record 36 of Set 13 | kharan
# Processing Record 37 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 13 | vitim
# Processing Record 39 of Set 13 | romitan
# Processing Record 40 of Set 13 | muroto
# Processing Record 41 of Set 13 | vao
# Processing Record 42 of Set 13 | marsaxlokk
# Processing Record 43 of Set 13 | henties bay
# Processing Record 44 of Set 13 | alghero
# Processing Record 45 of Set 13 | yenagoa
# Processing Record 46 of Set 13 | alofi
# Processing Record 47 of Set 13 | faya
# Processing Record 48 of Set 13 | offenburg
# Processing Record 49 of Set 13 | mwingi
# Processing Record 50 of Set 13 | saint-augustin
# Processing Record 1 of Set 14 | tromso
# Processing Record 2 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 14 | okhotsk
# Processing Record 4 of Set 14 | atakpame
# Processing Record 5 of Set 14 | tateyama
# Processing Record 6 of Set 14 | tamale
# Processing Record 7 of Set 14 | manzhouli
# Processing Record 8 of Set 14 | tarauaca
# Processing Record 9 of Set 14 | port hardy
# Processing Record 10 of Set 14 | muros
# Processing Record 11 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 12 of Set 14 | rudbar
# Processing Record 13 of Set 14 | sacu
# Processing Record 14 of Set 14 | lodja
# Processing Record 15 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 14 | rocha
# Processing Record 17 of Set 14 | lakselv
# Processing Record 18 of Set 14 | wajir
# Processing Record 19 of Set 14 | hay river
# Processing Record 20 of Set 14 | inuvik
# Processing Record 21 of Set 14 | kandry
# Processing Record 22 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 14 | nome
# Processing Record 24 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 14 | tawzar
# City not found. Skipping...
# Processing Record 26 of Set 14 | bogorodskoye
# Processing Record 27 of Set 14 | nuuk
# Processing Record 28 of Set 14 | mahajanga
# Processing Record 29 of Set 14 | petauke
# Processing Record 30 of Set 14 | yendi
# Processing Record 31 of Set 14 | lagoa
# Processing Record 32 of Set 14 | huasahuasi
# Processing Record 33 of Set 14 | aswan
# Processing Record 34 of Set 14 | marechal deodoro
# Processing Record 35 of Set 14 | redmond
# Processing Record 36 of Set 14 | mabai
# Processing Record 37 of Set 14 | leh
# Processing Record 38 of Set 14 | selu
# Processing Record 39 of Set 14 | yumen
# Processing Record 40 of Set 14 | garissa
# Processing Record 41 of Set 14 | chardara
# Processing Record 42 of Set 14 | ati
# Processing Record 43 of Set 14 | namatanai
# Processing Record 44 of Set 14 | long xuyen
# Processing Record 45 of Set 14 | acajutla
# Processing Record 46 of Set 14 | dakoro
# Processing Record 47 of Set 14 | listvyagi
# Processing Record 48 of Set 14 | voh
# Processing Record 49 of Set 14 | norfolk
# Processing Record 50 of Set 14 | fevik
# Processing Record 1 of Set 15 | sorong
# Processing Record 2 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 15 | le vauclin
# Processing Record 4 of Set 15 | ambon
# Processing Record 5 of Set 15 | columbus
# Processing Record 6 of Set 15 | ranong
# Processing Record 7 of Set 15 | octeville
# Processing Record 8 of Set 15 | tignoan
# Processing Record 9 of Set 15 | kargasok
# Processing Record 10 of Set 15 | faire
# City not found. Skipping...
# Processing Record 11 of Set 15 | maragogi
# Processing Record 12 of Set 15 | nishihara
# Processing Record 13 of Set 15 | sinegorye
# Processing Record 14 of Set 15 | chara
# Processing Record 15 of Set 15 | san carlos de bariloche
# Processing Record 16 of Set 15 | daye
# Processing Record 17 of Set 15 | qaqortoq
# Processing Record 18 of Set 15 | zarand
# Processing Record 19 of Set 15 | mantua
# Processing Record 20 of Set 15 | acapulco
# Processing Record 21 of Set 15 | margate
# Processing Record 22 of Set 15 | aksarka
# Processing Record 23 of Set 15 | karratha
# Processing Record 24 of Set 15 | serenje
# Processing Record 25 of Set 15 | pampierstad
# Processing Record 26 of Set 15 | ust-kut
# Processing Record 27 of Set 15 | daru
# Processing Record 28 of Set 15 | mokhsogollokh
# Processing Record 29 of Set 15 | wuwei
# Processing Record 30 of Set 15 | sigerfjord
# City not found. Skipping...
# Processing Record 31 of Set 15 | paamiut
# Processing Record 32 of Set 15 | visnes
# Processing Record 33 of Set 15 | uribia
# Processing Record 34 of Set 15 | hailar
# Processing Record 35 of Set 15 | bo rai
# Processing Record 36 of Set 15 | abu samrah
# Processing Record 37 of Set 15 | tatawin
# Processing Record 38 of Set 15 | tiksi
# Processing Record 39 of Set 15 | son la
# Processing Record 40 of Set 15 | kutum
# Processing Record 41 of Set 15 | rosarito
# Processing Record 42 of Set 15 | inverness
# Processing Record 43 of Set 15 | north bend
# Processing Record 44 of Set 15 | jiuquan
# Processing Record 45 of Set 15 | tignere
# Processing Record 46 of Set 15 | hobyo
# Processing Record 47 of Set 15 | opuwo
# Processing Record 48 of Set 15 | mangochi
# Processing Record 49 of Set 15 | pleasanton
# Processing Record 50 of Set 15 | galdar
# Processing Record 1 of Set 16 | xining
# Processing Record 2 of Set 16 | rawlins
# Processing Record 3 of Set 16 | pitimbu
# Processing Record 4 of Set 16 | turhal
# Processing Record 5 of Set 16 | banikoara
# Processing Record 6 of Set 16 | kysyl-syr
# Processing Record 7 of Set 16 | dehloran
# Processing Record 8 of Set 16 | ayan
# Processing Record 9 of Set 16 | bahia blanca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Tuatapere      NZ -46.1333  167.6833     48.00        80           4
# 1     Mataura      NZ -46.1927  168.8643     48.00        80          30
# 2      Atuona      PF  -9.8000 -139.0333     78.64        76           3
# 3   Jamestown      US  42.0970  -79.2353     21.00        73          90
# 4    Khatanga      RU  71.9667  102.5000    -45.09        73           0
# 5  Launceston      AU -41.4500  147.1667     62.60        94          90
# 6  Sao Filipe      CV  14.8961  -24.4956     75.13        63          84
# 7   Grindavik      IS  63.8424  -22.4338     35.60        75          90
# 8       Kapaa      US  22.0752 -159.3190     73.99        78          75
# 9      Tadine      NC -21.5500  167.8833     76.93        79          54
#
#    Wind Speed Current Description
# 0        8.01           clear sky
# 1        8.01    scattered clouds
# 2       18.92           clear sky
# 3       16.11          light snow
# 4        2.08           clear sky
# 5        9.22       moderate rain
# 6        9.60       broken clouds
# 7       10.36     overcast clouds
# 8       20.71       broken clouds
# 9       16.62       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
